# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt

# %%
mobile = tf.keras.applications.mobilenet.MobileNet()
# Out:
# ...
# 17235968/17225924 [==============================] - 0s 0us/step

# %%
def prepare_image(file):
    img_path = 'mobile/'
    img = image.load_img(img_path + file, target_size=(224,224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return tf.keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %%
from IPython.display import Image
Image(filename='mobile/36.jpg', width=300, height=200)

# %%
preprocessed_image = prepare_image('36.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n01774750', 'tarantula', 0.970788),
#   ('n01775062', 'wolf_spider', 0.024090812),
#   ('n01773549', 'barn_spider', 0.004599066),
#   ('n01773797', 'garden_spider', 0.0001505128),
#   ('n02865351', 'bolo_tie', 0.000115555464)]]

# %%
from IPython.display import Image
Image(filename='mobile/825.jpg', width=300, height=200)

# %%
preprocessed_image = prepare_image('825.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n07697313', 'cheeseburger', 0.9598112),
#   ('n07871810', 'meat_loaf', 0.010753979),
#   ('n07684084', 'French_loaf', 0.009615079),
#   ('n07693725', 'bagel', 0.009512453),
#   ('n03871628', 'packet', 0.0020209039)]]

# %%
from IPython.display import Image
Image(filename='mobile/618.jpg', width=300, height=200)

# %%
preprocessed_image = prepare_image('618.jpg')
predictions = mobile.predict(preprocessed_image)
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n01622779', 'great_grey_owl', 0.949565),
#   ('n01608432', 'kite', 0.04318621),
#   ('n01798484', 'prairie_chicken', 0.0038124549),
#   ('n01797886', 'ruffed_grouse', 0.0009650709),
#   ('n01796340', 'ptarmigan', 0.00034570094)]]
